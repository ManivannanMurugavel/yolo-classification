# %%
! ls
# Out:
# sample_data

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %%
import os, sys

# %%
os.getcwd()
# Out:
# '/content/darknet'

# %%
! git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15494, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15494 (delta 0), reused 1 (delta 0), pack-reused 15490
# Receiving objects: 100% (15494/15494), 14.11 MiB | 24.15 MiB/s, done.
# Resolving deltas: 100% (10408/10408), done.

# %%
 # %cd darknet/
# Out:
# /content/darknet

# %%
! ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
! make

# %%
# !wget https://pjreddie.com/media/files/darknet19.weights
# Out:
# --2022-10-20 06:52:33--  https://pjreddie.com/media/files/darknet19.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83427120 (80M) [application/octet-stream]
# Saving to: ‘darknet19.weights’
#
# darknet19.weights   100%[===================>]  79.56M  34.0MB/s    in 2.3s
#
# 2022-10-20 06:52:36 (34.0 MB/s) - ‘darknet19.weights’ saved [83427120/83427120]

# %%
! ./darknet classifier predict cfg/imagenet1k.data cfg/darknet19.cfg darknet19.weights data/dog.jpg
# Out:
#  CUDA-version: 11020 (11020), cuDNN: 8.1.1, GPU count: 1
#  OpenCV isn't used - data augmentation will be slow
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    224 x 224 x   3 ->  224 x 224 x  32 0.087 BF
#    1 max                2x 2/ 2    224 x 224 x  32 ->  112 x 112 x  32 0.002 BF
#    2 conv     64       3 x 3/ 1    112 x 112 x  32 ->  112 x 112 x  64 0.462 BF
#    3 max                2x 2/ 2    112 x 112 x  64 ->   56 x  56 x  64 0.001 BF
#    4 conv    128       3 x 3/ 1     56 x  56 x  64 ->   56 x  56 x 128 0.462 BF
#    5 conv     64       1 x 1/ 1     56 x  56 x 128 ->   56 x  56 x  64 0.051 BF
#    6 conv    128       3 x 3/ 1     56 x  56 x  64 ->   56 x  56 x 128 0.462 BF
# ...

# %%
# Upload the Cat and Dog dataset

# %%
! cd .. && unzip Images.zip

# %%
# Upload the cfg, data and names files

# %%
! ls
# Out:
# 3rdparty	darknet			image_yolov4.sh        README.md
# backup		darknet19.weights	include		       results
# build		DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# build.ps1	darknet_images.py	LICENSE		       src
# cfg		darknet.py		Makefile	       vcpkg.json
# classify.zip	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cmake		data			net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov3.sh		obj

# %%
! unzip classify.zip
# Out:
# Archive:  classify.zip
#    creating: classify/
#   inflating: classify/classify.data
#   inflating: classify/classify.names
#   inflating: classify/classify.labels
#   inflating: classify/darknet19.cfg

# %%
! ./darknet classifier train classify/classify.data classify/darknet19.cfg
# Out:
# Streaming output truncated to the last 5000 lines.
# Loaded: 0.000060 seconds
# 56219, 4475.144: 0.097649, 0.138416 avg, 0.086669 rate, 0.518271 seconds, 1799008 images, 151.603647 hours left
# Loaded: 0.000045 seconds
# 56220, 4475.224: 0.071144, 0.131689 avg, 0.086669 rate, 0.514174 seconds, 1799040 images, 151.628552 hours left
# Loaded: 0.000050 seconds
# 56221, 4475.303: 0.245273, 0.143047 avg, 0.086668 rate, 0.526168 seconds, 1799072 images, 151.752136 hours left
# Loaded: 0.000044 seconds
# 56222, 4475.383: 0.107084, 0.139451 avg, 0.086668 rate, 0.497782 seconds, 1799104 images, 151.698237 hours left
# Loaded: 0.000050 seconds
# 56223, 4475.462: 0.102019, 0.135708 avg, 0.086668 rate, 0.507206 seconds, 1799136 images, 151.608931 hours left
# Loaded: 0.000053 seconds
# 56224, 4475.542: 0.080282, 0.130165 avg, 0.086668 rate, 0.526363 seconds, 1799168 images, 151.656104 hours left
# Loaded: 0.000065 seconds
# ...

# %%
! ./darknet classifier predict classify/classify.data classify/darknet19.cfg darknet19_46000.weights cat.jpg
